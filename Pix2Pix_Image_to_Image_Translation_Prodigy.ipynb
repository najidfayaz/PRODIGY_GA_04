# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2619, done.
# remote: Total 2619 (delta 0), reused 0 (delta 0), pack-reused 2619 (from 1)
# Receiving objects: 100% (2619/2619), 8.24 MiB | 37.99 MiB/s, done.
# Resolving deltas: 100% (1654/1654), done.

# %%
# %cd pytorch-CycleGAN-and-pix2pix
# Out:
# /content/pytorch-CycleGAN-and-pix2pix

# %%
# !pip install torch
# !pip install transformers
# !pip install datasets
# !pip install tqdm
# !pip install dominate

# %%
# !bash ./datasets/download_pix2pix_dataset.sh edges2shoes
# Out:
# Streaming output truncated to the last 5000 lines.
# edges2shoes/train/46382_AB.jpg
# edges2shoes/train/46383_AB.jpg
# edges2shoes/train/46384_AB.jpg
# edges2shoes/train/46385_AB.jpg
# edges2shoes/train/46386_AB.jpg
# edges2shoes/train/46387_AB.jpg
# edges2shoes/train/46388_AB.jpg
# edges2shoes/train/46389_AB.jpg
# edges2shoes/train/4638_AB.jpg
# edges2shoes/train/46390_AB.jpg
# edges2shoes/train/46391_AB.jpg
# edges2shoes/train/46392_AB.jpg
# edges2shoes/train/449_AB.jpg
# edges2shoes/train/44_AB.jpg
# edges2shoes/train/45000_AB.jpg
# edges2shoes/train/45001_AB.jpg
# edges2shoes/train/45002_AB.jpg
# edges2shoes/train/45003_AB.jpg
# edges2shoes/train/45004_AB.jpg
# edges2shoes/train/45005_AB.jpg
# edges2shoes/train/45006_AB.jpg
# edges2shoes/train/45007_AB.jpg
# edges2shoes/train/45008_AB.jpg
# edges2shoes/train/45009_AB.jpg
# edges2shoes/train/4500_AB.jpg
# edges2shoes/train/45010_AB.jpg
# edges2shoes/train/45011_AB.jpg
# edges2shoes/train/45012_AB.jpg
# ...

# %%
# !ls datasets/edges2shoes
# Out:
# train  val

# %%
# !ls datasets/edges2shoes/train | head
# Out:
# 10000_AB.jpg
# 10001_AB.jpg
# 10002_AB.jpg
# 10003_AB.jpg
# 10004_AB.jpg
# 10005_AB.jpg
# 10006_AB.jpg
# 10007_AB.jpg
# 10008_AB.jpg
# 10009_AB.jpg

# %%
# !python train.py \
  --dataroot ./datasets/edges2shoes \
  --name edges2shoes_pix2pix \
  --model pix2pix \
  --direction AtoB \
  --batch_size 4 \
  --epoch_count 1 \
  --n_epochs 1 \
  --n_epochs_decay 0 \
  --no_html
# Out:
# ----------------- Options ---------------
#                batch_size: 4                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/edges2shoes        	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#              display_freq: 400
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                 lambda_L1: 100.0
#                 load_iter: 0                             	[default: 0]
#                 load_size: 286
#                        lr: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
# ...

# %%
# %cd /content/pytorch-CycleGAN-and-pix2pix
# Out:
# /content/pytorch-CycleGAN-and-pix2pix

# %%
# !pwd
# Out:
# /content/pytorch-CycleGAN-and-pix2pix

# %%
# !ls datasets
# Out:
# bibtex			      edges2shoes
# combine_A_and_B.py	      make_dataset_aligned.py
# download_cyclegan_dataset.sh  prepare_cityscapes_dataset.py
# download_pix2pix_dataset.sh

# %%
# !ls datasets/edges2shoes
# Out:
# train  val

# %%
cp -r datasets/edges2shoes/val datasets/edges2shoes/test

# %%
cp -r datasets/edges2shoes/train datasets/edges2shoes/test

# %%
# !ls datasets/edges2shoes
# Out:
# test  train  val

# %%
# !python test.py \
  --dataroot ./datasets/edges2shoes \
  --name edges2shoes_pix2pix \
  --model pix2pix \
  --direction AtoB
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/edges2shoes        	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: edges2shoes_pix2pix           	[default: experiment_name]
#                       ndf: 64
# ...

# %%
# !ls results/edges2shoes_pix2pix/test_latest/images
# Out:
# 100_AB_fake_B.png  111_AB_real_B.png  123_AB_real_A.png  135_AB_fake_B.png
# 100_AB_real_A.png  112_AB_fake_B.png  123_AB_real_B.png  135_AB_real_A.png
# 100_AB_real_B.png  112_AB_real_A.png  124_AB_fake_B.png  135_AB_real_B.png
# 101_AB_fake_B.png  112_AB_real_B.png  124_AB_real_A.png  136_AB_fake_B.png
# 101_AB_real_A.png  113_AB_fake_B.png  124_AB_real_B.png  136_AB_real_A.png
# 101_AB_real_B.png  113_AB_real_A.png  125_AB_fake_B.png  136_AB_real_B.png
# 102_AB_fake_B.png  113_AB_real_B.png  125_AB_real_A.png  137_AB_fake_B.png
# 102_AB_real_A.png  114_AB_fake_B.png  125_AB_real_B.png  137_AB_real_A.png
# 102_AB_real_B.png  114_AB_real_A.png  126_AB_fake_B.png  137_AB_real_B.png
# 103_AB_fake_B.png  114_AB_real_B.png  126_AB_real_A.png  138_AB_fake_B.png
# 103_AB_real_A.png  115_AB_fake_B.png  126_AB_real_B.png  138_AB_real_A.png
# 103_AB_real_B.png  115_AB_real_A.png  127_AB_fake_B.png  138_AB_real_B.png
# ...

# %%
from IPython.display import Image, display

display(Image('results/edges2shoes_pix2pix/test_latest/images/100_AB_real_A.png'))
display(Image('results/edges2shoes_pix2pix/test_latest/images/100_AB_fake_B.png'))
